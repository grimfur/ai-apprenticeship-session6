# %% [markdown]
# # Pandas and Visualisation Recap
# This notebook gives you a refresh on the pandas essentials needed for ML and data science workflows.
#
# We focus on:
# - Inspecting & understanding data
# - Accessing rows/columns
# - Cleaning & preprocessing
# - Joining
# - Groupby
# - Feature engineering
#
# ---

# %% [markdown]
# ## 1. Reading and Inspecting Data
#
# - `pd.read_csv()` / `read_excel()`
# - `.head()`, `.info()`, `.describe()`
# - Checking dtypes and spotting object-vs-int issues

# %%
import pandas as pd

# %%
titanic = pd.read_csv("data/titanic.csv")
titanic.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0     1.0       1.0                    Allen, Miss. Elisabeth Walton  female
# 1     1.0       1.0                   Allison, Master. Hudson Trevor    male
# 2     1.0       0.0                     Allison, Miss. Helen Loraine  female
# 3     1.0       0.0             Allison, Mr. Hudson Joshua Creighton    male
# 4     1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked  \
# 0  29.0000    0.0    0.0   24160  211.3375       B5        S
# 1   0.9167    1.0    2.0  113781  151.5500  C22 C26        S
# 2   2.0000    1.0    2.0  113781  151.5500  C22 C26        S
# 3  30.0000    1.0    2.0  113781  151.5500  C22 C26        S
# 4  25.0000    1.0    2.0  113781  151.5500  C22 C26        S
#
#                          home.dest   body boat
# 0                     St Louis, MO    NaN    2
# 1  Montreal, PQ / Chesterville, ON    NaN   11
# 2  Montreal, PQ / Chesterville, ON    NaN  NaN
# 3  Montreal, PQ / Chesterville, ON  135.0  NaN
# 4  Montreal, PQ / Chesterville, ON    NaN  NaN

# %%
titanic.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0     1.0       1.0                    Allen, Miss. Elisabeth Walton  female
# 1     1.0       1.0                   Allison, Master. Hudson Trevor    male
# 2     1.0       0.0                     Allison, Miss. Helen Loraine  female
# 3     1.0       0.0             Allison, Mr. Hudson Joshua Creighton    male
# 4     1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked  \
# 0  29.0000    0.0    0.0   24160  211.3375       B5        S
# 1   0.9167    1.0    2.0  113781  151.5500  C22 C26        S
# 2   2.0000    1.0    2.0  113781  151.5500  C22 C26        S
# 3  30.0000    1.0    2.0  113781  151.5500  C22 C26        S
# 4  25.0000    1.0    2.0  113781  151.5500  C22 C26        S
#
#                          home.dest   body boat
# 0                     St Louis, MO    NaN    2
# 1  Montreal, PQ / Chesterville, ON    NaN   11
# 2  Montreal, PQ / Chesterville, ON    NaN  NaN
# 3  Montreal, PQ / Chesterville, ON  135.0  NaN
# 4  Montreal, PQ / Chesterville, ON    NaN  NaN

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1310 entries, 0 to 1309
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   float64
#  1   survived   1309 non-null   float64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   float64
#  6   parch      1309 non-null   float64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  home.dest  745 non-null    object
#  12  body       121 non-null    float64
#  13  boat       486 non-null    object
# dtypes: float64(7), object(7)
# memory usage: 143.4+ KB

# %% [markdown]
# Do all object types look as they should?

# %%
titanic.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881135     0.498854     0.385027
# std       0.837836     0.486055    14.413500     1.041658     0.865560
# min       1.000000     0.000000     0.166700     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1308.000000  121.000000
# mean     33.295479  160.809917
# std      51.758668   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329200  328.000000

# %%
titanic.dtypes
# Out:
# pclass       float64
# survived     float64
# name          object
# sex           object
# age          float64
# sibsp        float64
# parch        float64
# ticket        object
# fare         float64
# cabin         object
# embarked      object
# home.dest     object
# body         float64
# boat          object
# dtype: object

# %%
titanic.isna().sum()
# Out:
# pclass          1
# survived        1
# name            1
# sex             1
# age           264
# sibsp           1
# parch           1
# ticket          1
# fare            2
# cabin        1015
# embarked        3
# home.dest     565
# body         1189
# boat          824
# dtype: int64

# %%
titanic.isnull().sum()

# %% [markdown]
# ### Task
# - Load the dataset animals.csv.
#
# - Show the first 5 rows.
#
# - Check the dtypes.
#
# - Identify any problems (object columns that should be numeric/datetime).

# %%
import pandas as pd
animals = pd.read_csv("data/animals.csv")
animals.head()
# Out:
#   IncidentNumber    DateTimeOfCall  CalYear  FinYear   TypeOfIncident  \
# 0         139091  01/01/2009 03:01     2009  2008/09  Special Service
# 1         275091  01/01/2009 08:51     2009  2008/09  Special Service
# 2        2075091  04/01/2009 10:07     2009  2008/09  Special Service
# 3        2872091  05/01/2009 12:27     2009  2008/09  Special Service
# 4        3553091  06/01/2009 15:23     2009  2008/09  Special Service
#
#    PumpCount  PumpHoursTotal  HourlyNominalCost(£)  IncidentNominalCost(£)  \
# 0        1.0             2.0                   255                   510.0
# 1        1.0             1.0                   255                   255.0
# 2        1.0             1.0                   255                   255.0
# 3        1.0             1.0                   255                   255.0
# 4        1.0             1.0                   255                   255.0
#
#                             FinalDescription AnimalGroupParent  \
# 0  DOG WITH JAW TRAPPED IN MAGAZINE RACK,B15               Dog
# 1          ASSIST RSPCA WITH FOX TRAPPED,B15               Fox
# 2                    DOG CAUGHT IN DRAIN,B15               Dog
# 3                  HORSE TRAPPED IN LAKE,J17             Horse
# 4              RABBIT TRAPPED UNDER SOFA,B15            Rabbit
#
#                                     PropertyType  \
# 0                      House - single occupancy
# 1                                       Railings
# 2                                 Pipe or drain
# 3  Intensive Farming Sheds (chickens, pigs etc)
# 4                      House - single occupancy
#
#         SpecialServiceTypeCategory  \
# 0          Other animal assistance
# 1          Other animal assistance
# 2  Animal rescue from below ground
# 3         Animal rescue from water
# 4          Other animal assistance
#
#                                   SpecialServiceType     Borough  \
# 0  Animal assistance involving livestock - Other ...     Croydon
# 1  Animal assistance involving livestock - Other ...     Croydon
# 2     Animal rescue from below ground - Domestic pet      Sutton
# 3             Animal rescue from water - Farm animal  Hillingdon
# 4  Animal assistance involving livestock - Other ...    Havering
#
#   StnGroundName AnimalClass  Code        London
# 0       Norbury      Mammal  00AH  Outer London
# 1      Woodside      Mammal  00AH  Outer London
# 2    Wallington      Mammal  00BF  Outer London
# 3       Ruislip      Mammal  00AS  Outer London
# 4   Harold Hill      Mammal  00AR  Outer London

# %%
animals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5752 entries, 0 to 5751
# Data columns (total 19 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   IncidentNumber              5752 non-null   object
#  1   DateTimeOfCall              5752 non-null   object
#  2   CalYear                     5752 non-null   int64
#  3   FinYear                     5752 non-null   object
#  4   TypeOfIncident              5752 non-null   object
#  5   PumpCount                   5716 non-null   float64
#  6   PumpHoursTotal              5716 non-null   float64
#  7   HourlyNominalCost(£)        5752 non-null   int64
#  8   IncidentNominalCost(£)      5716 non-null   float64
#  9   FinalDescription            5749 non-null   object
#  10  AnimalGroupParent           5752 non-null   object
#  11  PropertyType                5752 non-null   object
#  12  SpecialServiceTypeCategory  5752 non-null   object
#  13  SpecialServiceType          5752 non-null   object
#  14  Borough                     5748 non-null   object
#  15  StnGroundName               5752 non-null   object
#  16  AnimalClass                 5752 non-null   object
#  17  Code                        5742 non-null   object
#  18  London                      5742 non-null   object
# dtypes: float64(3), int64(2), object(14)
# memory usage: 853.9+ KB

# %%
animals.dtypes
# Out:
# IncidentNumber                 object
# DateTimeOfCall                 object
# CalYear                         int64
# FinYear                        object
# TypeOfIncident                 object
# PumpCount                     float64
# PumpHoursTotal                float64
# HourlyNominalCost(£)            int64
# IncidentNominalCost(£)        float64
# FinalDescription               object
# AnimalGroupParent              object
# PropertyType                   object
# SpecialServiceTypeCategory     object
# SpecialServiceType             object
# Borough                        object
# StnGroundName                  object
# AnimalClass                    object
# Code                           object
# London                         object
# dtype: object

# %%
animals.describe()
# Out:
#            CalYear    PumpCount  PumpHoursTotal  HourlyNominalCost(£)  \
# count  5752.000000  5716.000000     5716.000000           5752.000000
# mean   2013.378651     1.022393        1.185269            288.390647
# std       2.831969     0.162619        0.660178             28.439044
# min    2009.000000     1.000000        1.000000            255.000000
# 25%    2011.000000     1.000000        1.000000            260.000000
# 50%    2013.000000     1.000000        1.000000            290.000000
# 75%    2016.000000     1.000000        1.000000            326.000000
# max    2018.000000     4.000000       12.000000            333.000000
#
#        IncidentNominalCost(£)
# count             5716.000000
# mean               341.723233
# std                194.099991
# min                255.000000
# 25%                260.000000
# 50%                295.000000
# 75%                328.000000
# max               3912.000000

# %%
animals.isna().sum()
# Out:
# IncidentNumber                 0
# DateTimeOfCall                 0
# CalYear                        0
# FinYear                        0
# TypeOfIncident                 0
# PumpCount                     36
# PumpHoursTotal                36
# HourlyNominalCost(£)           0
# IncidentNominalCost(£)        36
# FinalDescription               3
# AnimalGroupParent              0
# PropertyType                   0
# SpecialServiceTypeCategory     0
# SpecialServiceType             0
# Borough                        4
# StnGroundName                  0
# AnimalClass                    0
# Code                          10
# London                        10
# dtype: int64

# %%
animals.isnull().sum()
# Out:
# IncidentNumber                 0
# DateTimeOfCall                 0
# CalYear                        0
# FinYear                        0
# TypeOfIncident                 0
# PumpCount                     36
# PumpHoursTotal                36
# HourlyNominalCost(£)           0
# IncidentNominalCost(£)        36
# FinalDescription               3
# AnimalGroupParent              0
# PropertyType                   0
# SpecialServiceTypeCategory     0
# SpecialServiceType             0
# Borough                        4
# StnGroundName                  0
# AnimalClass                    0
# Code                          10
# London                        10
# dtype: int64

# %%
animals.select_dtypes(include=['object']).columns
# Out:
# Index(['IncidentNumber', 'DateTimeOfCall', 'FinYear', 'TypeOfIncident',
#        'FinalDescription', 'AnimalGroupParent', 'PropertyType',
#        'SpecialServiceTypeCategory', 'SpecialServiceType', 'Borough',
#        'StnGroundName', 'AnimalClass', 'Code', 'London'],
#       dtype='object')

# %%
animals['IncidentNumber'].unique()
# Out:
# array(['139091', '275091', '2075091', ..., '138800-29092018',
#        '138957-29092018', '139509-30092018'], dtype=object)

# %%
animals['DateTimeOfCall'].unique()
# Out:
# array(['01/01/2009 03:01', '01/01/2009 08:51', '04/01/2009 10:07', ...,
#        '29/09/2018 16:49', '29/09/2018 21:10', '30/09/2018 21:39'],
#       dtype=object)

# %%
missing_mask = animals["PumpHoursTotal"].isna()

# %% [markdown]
# ## 2. Selecting Data: loc, iloc, boolean filters
#
# `.loc` - label-based
#
# `.iloc` - position-based
#
# Boolean filters are essential for feature engineering and cleaning.

# %%
# Rows where value > 50
titanic[titanic["age"] > 50]
# Out:
#       pclass  survived                                           name     sex  \
# 6        1.0       1.0              Andrews, Miss. Kornelia Theodosia  female
# 8        1.0       1.0  Appleton, Mrs. Edward Dale (Charlotte Lamson)  female
# 9        1.0       0.0                        Artagaveytia, Mr. Ramon    male
# 14       1.0       1.0           Barkworth, Mr. Algernon Henry Wilson    male
# 33       1.0       1.0                       Bonnell, Miss. Elizabeth  female
# ...      ...       ...                                            ...     ...
# 1068     3.0       0.0                      Nysveen, Mr. Johan Hansen    male
# 1225     3.0       0.0                             Storey, Mr. Thomas    male
# 1235     3.0       0.0                            Svensson, Mr. Johan    male
# 1261     3.0       1.0                         Turkula, Mrs. (Hedwig)  female
# 1287     3.0       0.0               Widegren, Mr. Carl/Charles Peter    male
#
#        age  sibsp  parch    ticket     fare cabin embarked  \
# 6     63.0    1.0    0.0     13502  77.9583    D7        S
# 8     53.0    2.0    0.0     11769  51.4792  C101        S
# 9     71.0    0.0    0.0  PC 17609  49.5042   NaN        C
# 14    80.0    0.0    0.0     27042  30.0000   A23        S
# 33    58.0    0.0    0.0    113783  26.5500  C103        S
# ...    ...    ...    ...       ...      ...   ...      ...
# 1068  61.0    0.0    0.0    345364   6.2375   NaN        S
# 1225  60.5    0.0    0.0      3701      NaN   NaN        S
# 1235  74.0    0.0    0.0    347060   7.7750   NaN        S
# 1261  63.0    0.0    0.0      4134   9.5875   NaN        S
# 1287  51.0    0.0    0.0    347064   7.7500   NaN        S
#
#                               home.dest   body boat
# 6                            Hudson, NY    NaN   10
# 8                   Bayside, Queens, NY    NaN    D
# 9                   Montevideo, Uruguay   22.0  NaN
# 14                        Hessle, Yorks    NaN    B
# 33    Birkdale, England Cleveland, Ohio    NaN    8
# ...                                 ...    ...  ...
# 1068                                NaN    NaN  NaN
# 1225                                NaN  261.0  NaN
# 1235                                NaN    NaN  NaN
# 1261                                NaN    NaN   15
# 1287                                NaN    NaN  NaN
#
# [95 rows x 14 columns]

# %%
# Using loc
titanic.loc[titanic["sex"] == "female"]
# Out:
#       pclass  survived                                             name  \
# 0        1.0       1.0                    Allen, Miss. Elisabeth Walton
# 2        1.0       0.0                     Allison, Miss. Helen Loraine
# 4        1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 6        1.0       1.0                Andrews, Miss. Kornelia Theodosia
# 8        1.0       1.0    Appleton, Mrs. Edward Dale (Charlotte Lamson)
# ...      ...       ...                                              ...
# 1286     3.0       1.0  Whabee, Mrs. George Joseph (Shawneene Abi-Saab)
# 1290     3.0       1.0                 Wilkes, Mrs. James (Ellen Needs)
# 1300     3.0       1.0          Yasbeck, Mrs. Antoni (Selini Alexander)
# 1304     3.0       0.0                             Zabour, Miss. Hileni
# 1305     3.0       0.0                            Zabour, Miss. Thamine
#
#          sex   age  sibsp  parch  ticket      fare    cabin embarked  \
# 0     female  29.0    0.0    0.0   24160  211.3375       B5        S
# 2     female   2.0    1.0    2.0  113781  151.5500  C22 C26        S
# 4     female  25.0    1.0    2.0  113781  151.5500  C22 C26        S
# 6     female  63.0    1.0    0.0   13502   77.9583       D7        S
# 8     female  53.0    2.0    0.0   11769   51.4792     C101        S
# ...      ...   ...    ...    ...     ...       ...      ...      ...
# 1286  female  38.0    0.0    0.0    2688    7.2292      NaN        C
# 1290  female  47.0    1.0    0.0  363272    7.0000      NaN        S
# 1300  female  15.0    1.0    0.0    2659   14.4542      NaN        C
# 1304  female  14.5    1.0    0.0    2665   14.4542      NaN        C
# 1305  female   NaN    1.0    0.0    2665   14.4542      NaN        C
#
#                             home.dest   body boat
# 0                        St Louis, MO    NaN    2
# 2     Montreal, PQ / Chesterville, ON    NaN  NaN
# 4     Montreal, PQ / Chesterville, ON    NaN  NaN
# 6                          Hudson, NY    NaN   10
# 8                 Bayside, Queens, NY    NaN    D
# ...                               ...    ...  ...
# 1286                              NaN    NaN    C
# 1290                              NaN    NaN  NaN
# 1300                              NaN    NaN  NaN
# 1304                              NaN  328.0  NaN
# 1305                              NaN    NaN  NaN
#
# [466 rows x 14 columns]

# %%
# Using iloc
titanic.iloc[0:5]
# Out:
#    pclass  survived                                             name     sex  \
# 0     1.0       1.0                    Allen, Miss. Elisabeth Walton  female
# 1     1.0       1.0                   Allison, Master. Hudson Trevor    male
# 2     1.0       0.0                     Allison, Miss. Helen Loraine  female
# 3     1.0       0.0             Allison, Mr. Hudson Joshua Creighton    male
# 4     1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked  \
# 0  29.0000    0.0    0.0   24160  211.3375       B5        S
# 1   0.9167    1.0    2.0  113781  151.5500  C22 C26        S
# 2   2.0000    1.0    2.0  113781  151.5500  C22 C26        S
# 3  30.0000    1.0    2.0  113781  151.5500  C22 C26        S
# 4  25.0000    1.0    2.0  113781  151.5500  C22 C26        S
#
#                          home.dest   body boat
# 0                     St Louis, MO    NaN    2
# 1  Montreal, PQ / Chesterville, ON    NaN   11
# 2  Montreal, PQ / Chesterville, ON    NaN  NaN
# 3  Montreal, PQ / Chesterville, ON  135.0  NaN
# 4  Montreal, PQ / Chesterville, ON    NaN  NaN

# %%
titanic.iloc[0:3, 2:4]
# Out:
#                              name     sex
# 0   Allen, Miss. Elisabeth Walton  female
# 1  Allison, Master. Hudson Trevor    male
# 2    Allison, Miss. Helen Loraine  female

# %% [markdown]
# ### Task
# - Select all incidents where PumpCount is greater than 1.
#
# - Using loc, show IncidentNumber, AnimalGroupParent, and Borough for incidents involving "Cat".
#
# - Using iloc, return rows 20–40 and the first 4 columns.

# %%
animals[animals["PumpCount"] > 1]
# Out:
#         IncidentNumber    DateTimeOfCall  CalYear  FinYear   TypeOfIncident  \
# 26             6970091  11/01/2009 10:11     2009  2008/09  Special Service
# 37            12451091  21/01/2009 10:33     2009  2008/09  Special Service
# 43            14691091  25/01/2009 12:11     2009  2008/09  Special Service
# 59            21166091  06/02/2009 09:08     2009  2008/09  Special Service
# 70            27805091  17/02/2009 13:23     2009  2008/09  Special Service
# ...                ...               ...      ...      ...              ...
# 5568   092389-09072018  09/07/2018 08:35     2018  2018/19  Special Service
# 5591   098400-17072018  17/07/2018 16:16     2018  2018/19  Special Service
# 5613   103432-24072018  24/07/2018 15:25     2018  2018/19  Special Service
# 5636   108578-31072018  31/07/2018 14:39     2018  2018/19  Special Service
# 5707  000014-03092018M  03/09/2018 02:47     2018  2018/19  Special Service
#
#       PumpCount  PumpHoursTotal  HourlyNominalCost(£)  IncidentNominalCost(£)  \
# 26          2.0             3.0                   255                   765.0
# 37          2.0             3.0                   255                   765.0
# 43          2.0             3.0                   255                   765.0
# 59          2.0             3.0                   255                   765.0
# 70          2.0             5.0                   255                  1275.0
# ...         ...             ...                   ...                     ...
# 5568        2.0             8.0                   333                  2664.0
# 5591        2.0             5.0                   333                  1665.0
# 5613        2.0             4.0                   333                  1332.0
# 5636        2.0             3.0                   333                   999.0
# 5707        2.0             3.0                   333                   999.0
#
#                                        FinalDescription  \
# 26                               DOG  STUCK IN LAKE,J15
# 37                  ASSIST RSPCA WITH RESCUING FOX, J15
# 43                                     DOG IN CANAL,J15
# 59                                      DOG IN LAKE,J15
# 70                              KITTEN STUCK IN MUD,J15
# ...                                                 ...
# 5568  HORSE TRAPPED IN DOORWAY ADDITIONAL FRU REQUES...
# 5591  PUPPY TRAPPED BETWEEN TWO HOUSES  FRU REQ FROM...
# 5613  ASSIST RSPCA WITH BIRD TRAPPED IN NETTING IN P...
# 5636  TRAPPED BLACK BIRD - 9M LADDER X 1  REQUESTED ...
# 5707                                                NaN
#
#                      AnimalGroupParent               PropertyType  \
# 26                                 Dog       Lake/pond/reservoir
# 37                                 Fox                     Beach
# 43                                 Dog               River/canal
# 59                                 Dog       Lake/pond/reservoir
# 70                                 Cat               River/canal
# ...                                ...                        ...
# 5568                             Horse       Animal harm outdoors
# 5591                               Dog  House - single occupancy
# 5613                              Bird       Lake/pond/reservoir
# 5636                              Bird  House - single occupancy
# 5707  Unknown - Heavy Livestock Animal       Animal harm outdoors
#
#      SpecialServiceTypeCategory  \
# 26     Animal rescue from water
# 37     Animal rescue from water
# 43     Animal rescue from water
# 59     Animal rescue from water
# 70     Animal rescue from water
# ...                         ...
# 5568    Other animal assistance
# 5591    Other animal assistance
# 5613   Animal rescue from water
# 5636  Animal rescue from height
# 5707    Other animal assistance
#
#                                   SpecialServiceType        Borough  \
# 26           Animal rescue from water - Domestic pet    Westminster
# 37              Wild animal rescue from water or mud        Lambeth
# 43           Animal rescue from water - Domestic pet       Hounslow
# 59           Animal rescue from water - Domestic pet  Epping Forest
# 70           Animal rescue from water - Domestic pet         Bexley
# ...                                              ...            ...
# 5568  Animal assistance - Lift heavy domestic animal     Hillingdon
# 5591                  Assist trapped domestic animal        Enfield
# 5613                 Animal rescue from water - Bird        Bromley
# 5636                Animal rescue from height - Bird         Camden
# 5707                 Animal harm involving livestock         Sutton
#
#        StnGroundName AnimalClass  Code        London
# 26        Kensington      Mammal  00BK  Inner London
# 37           Lambeth      Mammal  00AY  Inner London
# 43            Heston      Mammal  00AT  Outer London
# 59             Essex      Mammal   NaN  Inner London
# 70             Erith      Mammal  00AD  Outer London
# ...              ...         ...   ...           ...
# 5568      Hillingdon      Mammal  00AS  Outer London
# 5591        Edmonton      Mammal  00AK  Inner London
# 5613          Sidcup        Bird  00AF  Outer London
# 5636  West Hampstead        Bird  00AG  Outer London
# 5707      Wallington      Mammal  00BF  Outer London
#
# [116 rows x 19 columns]

# %%
animals.loc[
    animals["AnimalGroupParent"] == "Cat",
    ["IncidentNumber", "AnimalGroupParent", "Borough"]
]
# Out:
#        IncidentNumber AnimalGroupParent                 Borough
# 10            5186091               Cat                 Bromley
# 14            5724091               Cat    Richmond Upon Thames
# 15            5770091               Cat                 Croydon
# 16            5789091               Cat                Lewisham
# 20            6317091               Cat               Southwark
# ...               ...               ...                     ...
# 5744  137789-27092018               Cat  Hammersmith And Fulham
# 5747  138718-29092018               Cat  Hammersmith And Fulham
# 5748  138738-29092018               Cat          Waltham Forest
# 5749  138800-29092018               Cat                 Bromley
# 5751  139509-30092018               Cat                  Barnet
#
# [2846 rows x 3 columns]

# %%
animals.iloc[20:41, 0:4]
# Out:
#    IncidentNumber    DateTimeOfCall  CalYear  FinYear
# 20        6317091  10/01/2009 11:27     2009  2008/09
# 21        6353091  10/01/2009 12:26     2009  2008/09
# 22        6355091  10/01/2009 12:32     2009  2008/09
# 23        6378091  10/01/2009 13:05     2009  2008/09
# 24        6400091  10/01/2009 13:28     2009  2008/09
# 25        6530091  10/01/2009 16:38     2009  2008/09
# 26        6970091  11/01/2009 10:11     2009  2008/09
# 27        7051091  11/01/2009 12:32     2009  2008/09
# 28        7613091  12/01/2009 13:10     2009  2008/09
# 29        7720091  12/01/2009 16:39     2009  2008/09
# 30        8648091  14/01/2009 06:38     2009  2008/09
# 31        9252091  15/01/2009 12:38     2009  2008/09
# 32       10299091  17/01/2009 11:40     2009  2008/09
# 33       10470091  17/01/2009 18:08     2009  2008/09
# 34       10829091  18/01/2009 11:08     2009  2008/09
# 35       10976091  18/01/2009 16:19     2009  2008/09
# 36       12317091  21/01/2009 00:43     2009  2008/09
# 37       12451091  21/01/2009 10:33     2009  2008/09
# 38       12533091  21/01/2009 14:04     2009  2008/09
# 39       12770091  21/01/2009 21:55     2009  2008/09
# 40       13245091  22/01/2009 21:35     2009  2008/09

# %% [markdown]
# ## 3. Cleaning & Preprocessing
# Common operations:
# - Handling missing values
# - Fixing dtypes
# - String cleaning
# - Converting to datetime (if present)

# %%
# Fill missing ages
titanic["age"] = titanic["age"].fillna(titanic["age"].median())

# Fill missing Embarked values
titanic["embarked"] = titanic["embarked"].fillna(titanic["embarked"].mode()[0])

# Standardise strings
titanic["name"] = titanic["name"].str.lower()

# %% [markdown]
# ### Tasks
# - Fill missing PumpHoursTotal values with the median.
#
# - Ensure AnimalGroupParent is lowercase (for consistency).

# %%
animals["PumpHoursTotal"] = animals["PumpHoursTotal"].fillna(
    animals["PumpHoursTotal"].median()
)

# %%
animals["PumpHoursTotal"].isna().sum()
# Out:
# 0

# %%
animals["AnimalGroupParent"] = animals["AnimalGroupParent"].str.lower()

# %%
animals["Borough"] = animals["Borough"].str.strip().str.title()

# %% [markdown]
# ## 4. Joining DataFrames (merge + concat)
#
# `merge()` for adding extra info
#
# `concat()` for stacking datasets

# %%
pclass_info = pd.DataFrame({
    "pclass": [1,2,3],
    "class_description": ["Upper", "Middle", "Lower"]
})

merged = titanic.merge(pclass_info, on="pclass", how="left")
merged.head()

# %% [markdown]
# ### Task
# Merge the below lookup table into the animals dataframe.

# %%
animalclass_info = pd.DataFrame({
    "AnimalClass": ["Mammal", "Bird", "Reptile", "Fish"],
    "TemperatureType": ["Warm-blooded", "Warm-blooded", "Cold-blooded", "Cold-blooded"]
})

# %%
animals.head()
# Out:
#   IncidentNumber    DateTimeOfCall  CalYear  FinYear   TypeOfIncident  \
# 0         139091  01/01/2009 03:01     2009  2008/09  Special Service
# 1         275091  01/01/2009 08:51     2009  2008/09  Special Service
# 2        2075091  04/01/2009 10:07     2009  2008/09  Special Service
# 3        2872091  05/01/2009 12:27     2009  2008/09  Special Service
# 4        3553091  06/01/2009 15:23     2009  2008/09  Special Service
#
#    PumpCount  PumpHoursTotal  HourlyNominalCost(£)  IncidentNominalCost(£)  \
# 0        1.0             2.0                   255                   510.0
# 1        1.0             1.0                   255                   255.0
# 2        1.0             1.0                   255                   255.0
# 3        1.0             1.0                   255                   255.0
# 4        1.0             1.0                   255                   255.0
#
#                             FinalDescription AnimalGroupParent  \
# 0  DOG WITH JAW TRAPPED IN MAGAZINE RACK,B15               dog
# 1          ASSIST RSPCA WITH FOX TRAPPED,B15               fox
# 2                    DOG CAUGHT IN DRAIN,B15               dog
# 3                  HORSE TRAPPED IN LAKE,J17             horse
# 4              RABBIT TRAPPED UNDER SOFA,B15            rabbit
#
#                                     PropertyType  \
# 0                      House - single occupancy
# 1                                       Railings
# 2                                 Pipe or drain
# 3  Intensive Farming Sheds (chickens, pigs etc)
# 4                      House - single occupancy
#
#         SpecialServiceTypeCategory  \
# 0          Other animal assistance
# 1          Other animal assistance
# 2  Animal rescue from below ground
# 3         Animal rescue from water
# 4          Other animal assistance
#
#                                   SpecialServiceType     Borough  \
# 0  Animal assistance involving livestock - Other ...     Croydon
# 1  Animal assistance involving livestock - Other ...     Croydon
# 2     Animal rescue from below ground - Domestic pet      Sutton
# 3             Animal rescue from water - Farm animal  Hillingdon
# 4  Animal assistance involving livestock - Other ...    Havering
#
#   StnGroundName AnimalClass  Code        London
# 0       Norbury      Mammal  00AH  Outer London
# 1      Woodside      Mammal  00AH  Outer London
# 2    Wallington      Mammal  00BF  Outer London
# 3       Ruislip      Mammal  00AS  Outer London
# 4   Harold Hill      Mammal  00AR  Outer London

# %% [markdown]
# ## 5. Groupby & Aggregation
# Useful for summarising:
# - Means
#
# - Totals
#
# - Counts

# %%
titanic.groupby("sex")["survived"].mean()

# %% [markdown]
# ### Tasks
#
# - Find the number of incidents per AnimalGroupParent.
#
# - Compute the average incident cost (IncidentNominalCost(£)) per Borough.
#
# - Find the total PumpHoursTotal per TypeOfIncident.

# %%
animals.groupby("AnimalGroupParent").size()
# Out:
# AnimalGroupParent
# bird                                                1082
# budgie                                                 2
# bull                                                   1
# cat                                                 2846
# cow                                                    7
# deer                                                  85
# dog                                                  988
# ferret                                                 5
# fish                                                   2
# fox                                                  229
# goat                                                   1
# hamster                                               14
# hedgehog                                               1
# horse                                                158
# lamb                                                   2
# lizard                                                 3
# pigeon                                                 4
# rabbit                                                10
# sheep                                                  4
# snake                                                  8
# squirrel                                              42
# tortoise                                               1
# unknown - animal rescue from water - farm animal       2
# unknown - domestic animal or pet                     156
# unknown - heavy livestock animal                      45
# unknown - wild animal                                 54
# dtype: int64

# %%
animals.groupby("AnimalClass").size()
# Out:
# AnimalClass
# Bird       1088
# Fish          2
# Mammal     4650
# Reptile      12
# dtype: int64

# %%
animals.groupby("Borough")["IncidentNominalCost(£)"].mean().sort_values(ascending=False)
# Out:
# Borough
# Epping Forest             649.666667
# Bexley                    421.525000
# Bromley                   398.554502
# Hillingdon                386.807487
# Enfield                   377.129555
# Waltham Forest            370.891626
# Havering                  366.750000
# Camden                    358.230769
# Tower Hamlets             358.042254
# Hounslow                  356.450980
# Redbridge                 350.206522
# Wandsworth                346.038889
# Greenwich                 344.088398
# Kingston Upon Thames      340.938053
# Richmond Upon Thames      334.407643
# Barnet                    333.723404
# Harrow                    330.897196
# Southwark                 328.868778
# Hammersmith And Fulham    328.097222
# Croydon                   326.569038
# Newham                    326.148718
# Ealing                    323.004975
# Westminster               322.365517
# Haringey                  320.866995
# Hackney                   319.465000
# Barking And Dagenham      319.277027
# Brent                     317.974194
# Merton                    316.660870
# Sutton                    315.708661
# Lambeth                   315.306306
# Islington                 314.668342
# Lewisham                  314.239362
# Kensington And Chelsea    313.392000
# City Of London            302.909091
# Tandridge                 295.000000
# Broxbourne                260.000000
# Brentwood                 260.000000
# Name: IncidentNominalCost(£), dtype: float64

# %%
animals.groupby("TypeOfIncident")["PumpHoursTotal"].sum()
# Out:
# TypeOfIncident
# Special Service    6811.0
# Name: PumpHoursTotal, dtype: float64

# %% [markdown]
# ## 6. Feature Engineering
# New columns, binning, mappings, ratios.

# %%
titanic["familysize"] = titanic["sibsp"] + titanic["parch"] + 1

# %%
titanic.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0     1.0       1.0                    Allen, Miss. Elisabeth Walton  female
# 1     1.0       1.0                   Allison, Master. Hudson Trevor    male
# 2     1.0       0.0                     Allison, Miss. Helen Loraine  female
# 3     1.0       0.0             Allison, Mr. Hudson Joshua Creighton    male
# 4     1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked  \
# 0  29.0000    0.0    0.0   24160  211.3375       B5        S
# 1   0.9167    1.0    2.0  113781  151.5500  C22 C26        S
# 2   2.0000    1.0    2.0  113781  151.5500  C22 C26        S
# 3  30.0000    1.0    2.0  113781  151.5500  C22 C26        S
# 4  25.0000    1.0    2.0  113781  151.5500  C22 C26        S
#
#                          home.dest   body boat  familysize
# 0                     St Louis, MO    NaN    2         1.0
# 1  Montreal, PQ / Chesterville, ON    NaN   11         4.0
# 2  Montreal, PQ / Chesterville, ON    NaN  NaN         4.0
# 3  Montreal, PQ / Chesterville, ON  135.0  NaN         4.0
# 4  Montreal, PQ / Chesterville, ON    NaN  NaN         4.0

# %% [markdown]
# ### Task
# Create a feature CostPerPumpHour = IncidentNominalCost(£) / PumpHoursTotal.

# %%
animals["CostPerPumpHour"] = (
    animals["IncidentNominalCost(£)"] / animals["PumpHoursTotal"]
)

# %%
animals.head()
# Out:
#   IncidentNumber    DateTimeOfCall  CalYear  FinYear   TypeOfIncident  \
# 0         139091  01/01/2009 03:01     2009  2008/09  Special Service
# 1         275091  01/01/2009 08:51     2009  2008/09  Special Service
# 2        2075091  04/01/2009 10:07     2009  2008/09  Special Service
# 3        2872091  05/01/2009 12:27     2009  2008/09  Special Service
# 4        3553091  06/01/2009 15:23     2009  2008/09  Special Service
#
#    PumpCount  PumpHoursTotal  HourlyNominalCost(£)  IncidentNominalCost(£)  \
# 0        1.0             2.0                   255                   510.0
# 1        1.0             1.0                   255                   255.0
# 2        1.0             1.0                   255                   255.0
# 3        1.0             1.0                   255                   255.0
# 4        1.0             1.0                   255                   255.0
#
#                             FinalDescription AnimalGroupParent  \
# 0  DOG WITH JAW TRAPPED IN MAGAZINE RACK,B15               dog
# 1          ASSIST RSPCA WITH FOX TRAPPED,B15               fox
# 2                    DOG CAUGHT IN DRAIN,B15               dog
# 3                  HORSE TRAPPED IN LAKE,J17             horse
# 4              RABBIT TRAPPED UNDER SOFA,B15            rabbit
#
#                                     PropertyType  \
# 0                      House - single occupancy
# 1                                       Railings
# 2                                 Pipe or drain
# 3  Intensive Farming Sheds (chickens, pigs etc)
# 4                      House - single occupancy
#
#         SpecialServiceTypeCategory  \
# 0          Other animal assistance
# 1          Other animal assistance
# 2  Animal rescue from below ground
# 3         Animal rescue from water
# 4          Other animal assistance
#
#                                   SpecialServiceType     Borough  \
# 0  Animal assistance involving livestock - Other ...     Croydon
# 1  Animal assistance involving livestock - Other ...     Croydon
# 2     Animal rescue from below ground - Domestic pet      Sutton
# 3             Animal rescue from water - Farm animal  Hillingdon
# 4  Animal assistance involving livestock - Other ...    Havering
#
#   StnGroundName AnimalClass  Code        London  CostPerPumpHour
# 0       Norbury      Mammal  00AH  Outer London            255.0
# 1      Woodside      Mammal  00AH  Outer London            255.0
# 2    Wallington      Mammal  00BF  Outer London            255.0
# 3       Ruislip      Mammal  00AS  Outer London            255.0
# 4   Harold Hill      Mammal  00AR  Outer London            255.0

# %% [markdown]
# ## 7. Seaborn Recap

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(style="whitegrid")

# %% [markdown]
# ### A. Categorical Plots
# - Countplot
# - Barplot
# - Coloured by hue

# %%
sns.countplot(data=titanic, x="pclass", hue="sex")
plt.title("Passenger Class by Sex")
plt.show()

# %% [markdown]
# #### Task
#
# Plot a count of incidents per AnimalClass.
#
# Create a barplot showing the average incident cost (IncidentNominalCost(£)) per TypeOfIncident.
#
# Repeat the barplot but add a hue="AnimalClass" to compare mammals, birds, reptiles, and fish.

# %%
sns.countplot(data=animals, x="Incidents", hue="AnimalClass")
plt.title("incidents per animalclass")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 sns.countplot(data=animals, x="Incidents", hue="AnimalClass")
#       2 plt.title("incidents per animalclass")
#       3 plt.show()
#
# File c:\Users\Dean\.conda\envs\ai-training\Lib\site-packages\seaborn\categorical.py:2943, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2940 elif x is not None and y is not None:
#    2941     raise ValueError("Cannot pass values for both `x` and `y`")
# -> 2943 plotter = _CountPlotter(
#    2944     x, y, hue, data, order, hue_order,
#    2945     estimator, errorbar, n_boot, units, seed,
#    2946     orient, color, palette, saturation,
#    2947     width, errcolor, errwidth, capsize, dodge
#    2948 )
#    2950 plotter.value_label = "count"
#    2952 if ax is None:
#
# File c:\Users\Dean\.conda\envs\ai-training\Lib\site-packages\seaborn\categorical.py:1530, in _BarPlotter.__init__(self, x, y, hue, data, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge)
#    1525 def __init__(self, x, y, hue, data, order, hue_order,
#    1526              estimator, errorbar, n_boot, units, seed,
#    1527              orient, color, palette, saturation, width,
#    1528              errcolor, errwidth, capsize, dodge):
#    1529     """Initialize the plotter."""
# -> 1530     self.establish_variables(x, y, hue, data, orient,
#    1531                              order, hue_order, units)
#    1532     self.establish_colors(color, palette, saturation)
#    1533     self.estimate_statistic(estimator, errorbar, n_boot, seed)
#
# File c:\Users\Dean\.conda\envs\ai-training\Lib\site-packages\seaborn\categorical.py:541, in _CategoricalPlotter.establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     539     if isinstance(var, str):
#     540         err = f"Could not interpret input '{var}'"
# --> 541         raise ValueError(err)
#     543 # Figure out the plotting orientation
#     544 orient = infer_orient(
#     545     x, y, orient, require_numeric=self.require_numeric
#     546 )
#
# ValueError: Could not interpret input 'Incidents'

# %%
sns.countplot(data=animals, x="AnimalGroupParent", hue="AnimalClass")
plt.title("Incidents per Animal Class")
plt.show()

# %%
sns.countplot(data=animals, x="AnimalGroupParent", hue="AnimalClass")
# Out:
# <Axes: xlabel='AnimalGroupParent', ylabel='count'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(data=animals, x="AnimalClass")
plt.title("Number of Incidents per Animal Class")
plt.xticks(rotation=45)
plt.show()

# %%
sns.barplot(
    data=animals,
    x="TypeOfIncident",
    y="IncidentNominalCost(£)"
)
plt.title("Average Incident Cost per Type of Incident")
plt.xticks(rotation=45)
plt.show()

# %%
sns.barplot(
    data=animals,
    x="TypeOfIncident",
    y="IncidentNominalCost(£)",
    hue="AnimalClass"
)
plt.title("Average Incident Cost per Type of Incident by Animal Class")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### B) Distribution Plots
# - Histplot
#
# - KDE overlay
#
# - Split by hue

# %%
sns.histplot(data=titanic, x="age", hue="survived", kde=True)
plt.show()

# %%
sns.displot(
    data=titanic,
    x="age",
    hue="survived",
    col="pclass",
    kde=True
)

# %% [markdown]
# ### Task
# Plot the distribution of PumpHoursTotal.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(data=animals, x="PumpHoursTotal", bins=30)
plt.title("Distribution of Pump Hours Total")
plt.xlabel("PumpHoursTotal")
plt.ylabel("Frequency")
plt.show()

# %%
sns.histplot(data=animals, x="PumpHoursTotal", bins=30, kde=True)
plt.title("Distribution of Pump Hours Total (with KDE)")
plt.show()

# %%
sns.kdeplot(data=animals, x="PumpHoursTotal")
plt.title("Density Plot of Pump Hours Total")
plt.show()

# %%
titanic["class_survival"] = (
    titanic["pclass"].astype(str) + "_" + titanic["survived"].astype(str)
)

sns.histplot(
    data=titanic,
    x="age",
    hue="class_survival",
    kde=True
)
plt.show()

# %% [markdown]
# ### C) Relationship Plots
# - Scatter
#
# - Box
#
# - Violin

# %%
sns.boxplot(data=titanic, x="pclass", y="fare")
plt.show()

# %% [markdown]
# #### Tasks
#
# Create a scatterplot of PumpHoursTotal vs IncidentNominalCost(£) coloured by AnimalClass.
#
# Create a boxplot of IncidentNominalCost(£) by AnimalGroupParent.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.scatterplot(
    data=animals,
    x="PumpHoursTotal",
    y="IncidentNominalCost(£)",
    hue="AnimalClass"
)

plt.title("Pump Hours vs Incident Cost by Animal Class")
plt.xlabel("PumpHoursTotal")
plt.ylabel("IncidentNominalCost(£)")
plt.show()

# %%
sns.boxplot(
    data=animals,
    x="AnimalGroupParent",
    y="IncidentNominalCost(£)"
)

plt.title("Incident Cost Distribution by Animal Group")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### D) Correlation Heatmap
# Good for quick EDA.

# %%
corr = titanic.corr(numeric_only=True)
sns.heatmap(corr, annot=True, cmap="coolwarm")
plt.show()

# %% [markdown]
# #### Task
# Create a correlation heatmap of all numeric columns in the animals dataset.

# %%
numeric_cols = animals.select_dtypes(include=["number"])

# %%
corr = numeric_cols.corr()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 8))

sns.heatmap(
    corr,
    annot=True,
    fmt=".2f",
    cmap="coolwarm",
    linewidths=0.5
)

plt.title("Correlation Heatmap of Numeric Features")
plt.show()

# %%
import numpy as np

mask = np.triu(np.ones_like(corr, dtype=bool))

sns.heatmap(
    corr,
    mask=mask,
    annot=True,
    fmt=".2f",
    cmap="coolwarm"
)
plt.show()
# Out:
# c:\Users\Dean\.conda\envs\ai-training\Lib\site-packages\seaborn\matrix.py:260: FutureWarning: Format strings passed to MaskedConstant are ignored, but in future may error or produce different behavior
#   annotation = ("{:" + self.fmt + "}").format(val)
